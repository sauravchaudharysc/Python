# %% [markdown]
# # Data Visualization
# Source https://www.geeksforgeeks.org/data-visualization-different-charts-python/

# %% [markdown]
# Data Visualization is the presentation of data in graphical format. It helps people understand the significance of data by summarizing and presenting huge amount of data in a simple and easy-to-understand format and helps communicate information clearly and effectively.
#
# An important concept when we solve any data science or machine learning problem. Because every problem has to go through certain steps.
#
# 1. 	Understand the Problem Statement
# 2.  Acquire Data & Cleaning
# 3.  Data Visualization / Exploratory Analysis
# 4.  Machine Learning Modelling
# 5.  Share Results/ Interesting Visualizations about findings.
#
# So data visualizations comes in picture at two stages.
#
# -	Before Modelling, how data look like.
# -	While sharing some result .
#
# Different Types of Charts for Analyzing & Presenting Data
#
# ​ Line Plot
# ​ Scatter Plot
# ​ Histogram
# ​ Column Chart
# ​ Pie Chart

# %% [markdown]
# ### Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
# To plot a line
x= np.arange(100)
y= x**2+10
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Scatter Plot
#
# You get points here instead of line. It should be used when there are many different data points, and you want to highlight similarities in the data set. This is useful when looking for outliers and for understanding the distribution of your data.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,2,3,4,5,2.8])
y= x**2+3+x**4
plt.scatter(x, y, c ="blue") 
plt.show()

# %% [markdown]
# ### Histogram
# BarGraph Representation

# %%
# import pandas and matplotlib 
import pandas as pd 
import matplotlib.pyplot as plt 
  
# create 2D array of table given above 
data = [['E001', 'M', 34, 123, 'Normal', 350], 
        ['E002', 'F', 40, 114, 'Overweight', 450], 
        ['E003', 'F', 37, 135, 'Obesity', 169], 
        ['E004', 'M', 30, 139, 'Underweight', 189], 
        ['E005', 'F', 44, 117, 'Underweight', 183], 
        ['E006', 'M', 36, 121, 'Normal', 80], 
        ['E007', 'M', 32, 133, 'Obesity', 166], 
        ['E008', 'F', 26, 140, 'Normal', 120], 
        ['E009', 'M', 32, 133, 'Normal', 75], 
        ['E010', 'M', 36, 133, 'Underweight', 40] ] 
  
# dataframe created with 
# the above data array 
df = pd.DataFrame(data, columns = ['EMPID', 'Gender',  
                                    'Age', 'Sales', 
                                    'BMI', 'Income'] ) 
  
# create histogram for numeric data 
df.hist() 
  
# show plot 
plt.show()

# %% [markdown]
# ### Column Chart
# A column chart is used to show a comparison among different attributes

# %%
df.plot.bar() 
  
# plot between 2 attributes 
plt.bar(df['Age'], df['Sales']) 
plt.xlabel("Age") 
plt.ylabel("Sales") 
plt.show()

# %% [markdown]
# ### Pie Chart
# A circular statistical graph which is divided into slice to illustrate numerical proportion
#
# To get description
# plt.pie?

# %%
subjects = "Data Structure","Algorithms","Folt","Java","Analog & Digital"
weightage = [20,10,15,30,8]
plt.pie(weightage,labels=subjects,explode=(0,0,0,0,0.1))
plt.show()

# %%
plt.pie(df['Age'], labels = {"A", "B", "C", 
                             "D", "E", "F", 
                             "G", "H", "I", "J"}, 
                               
autopct ='% 1.1f %%', shadow = True) 
plt.show()

# %% [markdown]
# ## Practical
# ### Install Matplotlib
# pip install matplotlib

# %% [markdown]
# Data Science Pipeline
# -------------------------------
# ##### -Understand the Problem Statement
# ##### -Acquire Data & Cleaning
# ##### -Data Visualisation / Exploratory Analysis
# ##### -Machine Learning Modelling
# ##### -Share Results/Interesting Visualisations about findings

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Line Plot
x = np.arange(10)
y1 = x**2
y2 = 2*x+3
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
#Themes available
thems = plt.style.available
print(thems)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('seaborn')
plt.plot(x,y1,color='red')
plt.plot(x,y2,color='blue')

plt.show()

# %%
plt.style.use('seaborn')
plt.plot(x,y1,color='red')
plt.plot(x,y2,color='blue')
#this output wont be shown outside jupyter notebook because its a object
#its ability of jupyter to show it. So we need to use plt.show()
#plt.show() also indicates that graph is completed

# %%
plt.style.use('seaborn')
plt.plot(x,y1,color='red')
plt.show()
plt.plot(x,y2,color='blue')
plt.show()

# %%
#To give titles
plt.style.use('seaborn')
plt.plot(x,y1,color='red')
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.show()

# %%
#To show color indication
plt.style.use('seaborn')
plt.plot(x,y1,color='red',label="Kiwi")
plt.plot(x,y2,color='blue',label="Mango")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.legend()
plt.show()

# %%
#All function to see documentation
plt.plot?

# %%
#To show color indication
plt.style.use('seaborn')
plt.plot(x,y1,color='red',label="Kiwi",linestyle="dashed")
plt.plot(x,y2,color='blue',label="Mango")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.legend()
plt.show()

# %%
#To show color indication
plt.style.use('seaborn')
plt.plot(x,y1,color='red',label="Kiwi",marker='o')
plt.plot(x,y2,color='blue',label="Mango",marker='*')
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.legend()
plt.show()
