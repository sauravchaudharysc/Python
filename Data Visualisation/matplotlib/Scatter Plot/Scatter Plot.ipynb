# %% [markdown]
# # Scatter Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
prices = np.array([1,2,3,4])**3
print(prices)
# Out:
# [ 1  8 27 64]

# %%
#this will become y 
#and x will become 1,2,3
plt.plot(prices)

# %%
x = np.arange(10)
y1 = x**2
y2 = 2*x+3

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.style.use('seaborn')
plt.scatter(x,y1,color='red',label="Kiwi",marker='^')
plt.scatter(x,y2,color='blue',label="Mango")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.legend()
plt.show()

# %%
#Adjust size of plot
plt.figure(figsize=(5,5))
plt.scatter(x,y1,color='red',label="Kiwi",marker='^')
plt.scatter(x,y2,color='blue',label="Mango")
plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Fruits")
plt.legend()
plt.show()
